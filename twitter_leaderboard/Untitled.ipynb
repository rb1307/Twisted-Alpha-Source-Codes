# %%
import pandas as pd 

df=pd.read_excel("/home/hp/PINGALA ANALYTICS/SM Management Tool/pingala_v2/final.xlsx")
df.head()
# Out:
#        Leader name  Retweet Count  Applause Rate Tweet Type  \
# 0  sarbanandsonwal             47            200      quote
# 1  sarbanandsonwal             57            241      quote
# 2  sarbanandsonwal            121            383      tweet
# 3  sarbanandsonwal             40            133      tweet
# 4  sarbanandsonwal           4746              0    retweet
#
#    Tweet Engagement(per 1K followers) Business Objective  \
# 0                            0.285396                CMS
# 1                            0.340022                CMS
# 2                            0.587514                CMS
# 3                            0.215162                CMS
# 4                            0.000000                CMS
#
#                                                 Link
# 0  https://twitter.com/rsarbanandsonwal/status/13...
# 1  https://twitter.com/rsarbanandsonwal/status/13...
# 2  https://twitter.com/rsarbanandsonwal/status/13...
# ...

# %%
df.drop_duplicates(subset =["Link"], 
                     keep = "first", inplace = True)

# %%
len(df)
# Out:
# 41

# %%
df
# Out:
#         Leader name  Retweet Count  Applause Rate Tweet Type  \
# 0   sarbanandsonwal             47            200      quote
# 1   sarbanandsonwal             57            241      quote
# 2   sarbanandsonwal            121            383      tweet
# 3   sarbanandsonwal             40            133      tweet
# 4   sarbanandsonwal           4746              0    retweet
# 5   sarbanandsonwal             85           1001      tweet
# 6   sarbanandsonwal             75            300      tweet
# 7   sarbanandsonwal             71            312      tweet
# 8      himantabiswa            123            993      quote
# 9      himantabiswa           1176              0    retweet
# 10     himantabiswa            126           1093      tweet
# 11    RanjeetkrDass           1174              0    retweet
# 12    RanjeetkrDass             50            145      tweet
# 13    RanjeetkrDass             20             47      quote
# ...
